# %%
from deepface.commons import functions
import cv2

# %%
img1 = functions.detectFace("image5.jpg", imput_shpae)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3076\2904171560.py in <module>
# ----> 1 img1 = functions.detectFace("image5.jpg", imput_shpae)
#
# AttributeError: module 'deepface.commons.functions' has no attribute 'detectFace'

# %%
from deepface import DeepFace

# %%
image1 =DeepFace.extract_faces(img_path = "image1.jpg", target_size = (224,224), detector_backend = "opencv")

# %%
print(image1.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3076\152680082.py in <module>
# ----> 1 print(image1.shape)
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
cv2.imshow(image1, image1)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3076\1293904386.py in <module>
# ----> 1 cv2.imshow(image1, image1)
#
# error: OpenCV(4.7.0) :-1: error: (-5:Bad argument) in function 'imshow'
# > Overload resolution failed:
# >  - Can't convert object to 'str' for 'winname'
# >  - Can't convert object to 'str' for 'winname'
# >  - Can't convert object to 'str' for 'winname'

# %%
import cv2
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img
from retinaface import RetinaFace
fig = plt.figure()

for i in range(5):
    faces = RetinaFace.extract_faces(img_path = "../data/images/Class/Class{}.JPG".format(i), align = True)
    img = plt.imread("../data/images/Class/Class{}.jpg".format(i))
    plt.figure(1,4)
    plt.imshow(img)
    for i, face in enumerate(faces):
        plt.subplot(3,3,i+1)
        plt.imshow(face)

# %%
for i, face in enumerate(faces):
    face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
    cv2.imwrite("test{}.jpg".format(i+1), face)

# %%
for i, face in enumerate(faces):
    img_bgr = cv2.imread('images{}.jpg'.format(i))
    cv2.imshow("face",face)

# %%
import tensorflow as tf
tf.test.is_gpu_available()
# Out:
# True

# %%
print(face.shape)
# Out:
# (339, 237, 3)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from retinaface import RetinaFace

fig, axs = plt.subplots(5, 6, figsize=(16, 16))

for i in range(5):
    # Load image
    img = mpimg.imread("../data/images/Class/Class{}.JPG".format(i))

    # Extract faces using RetinaFace
    faces = RetinaFace.extract_faces(img_path="../data/images/Class/Class{}.JPG".format(i), align=True)

    # Show original image
    axs[i, 0].imshow(img)
    axs[i, 0].set_title("class{}.jpg".format(i))

    # Show extracted faces
    for j, face in enumerate(faces):
        axs[i, j+1].imshow(face)
        axs[i, j+1].set_title("Face {}".format(j+1))

# Hide axis ticks and labels
for ax in axs.flatten():
    ax.axis("off")

plt.tight_layout()
plt.show()
